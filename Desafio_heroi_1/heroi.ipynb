# %%
import random
import sys

nome = input('Digite o nome do seu heroi: ')
exp = 0
print(f'O herói {nome} tem {exp} pontos de experiência.')
def Jogo():
    print('Vamos treinar esse heroi?')
    print("1 - Vamos comer Salada - Acrescentar 1.000 pontos de experiência")
    print("2 - Levantar barras de FERRO acrescenta 5.000 pontos de experiência")
    print("3 - Comer um quadrado de Chocolate acrescenta 10.000 pontos de experiência")
    print("4 - Comer uma barra de Chocolate - 'Se uma quadrado dá isso de pontos...'")
    print("5 - Cansei da brincadeira")
    Regra()
def Regra():
    global exp
    regra = input("Escolha uma das opções: ")
    
    if regra == "1":
        print("Escolha saudável")
        exp += 1000
    elif regra == "2":
        print(f"Aqui é BODYBUILDER disse o {nome}")
        exp += 5000
    elif  regra == "3":
        print("Cuidado...")
        print("Não vai se perder nesse mundo...")
        exp += 10000
    elif regra == "4":
        print("Olha a besteira que você fez")
        exp += random.randint(-10000, 1000)
    elif regra == "5":
        print("Vamos sair")
        sys.exit()
    else:
        print(f"Escolha uma opção válida, {nome}")
    
    print(f'Você escolheu {regra}, atribuindo {exp} pontos ao {nome}.')
    Xp()
def Xp():
    global exp
    global xp_log
    xp_log = "Fracote"
    if exp == 0:
        xp_log = "FRANGO"
    elif exp > 1 and exp < 1000:
        xp_log = "Ferro"
    elif exp >= 1001 and exp < 2000:
        xp_log = "Bronze"
    elif exp >= 2001 and exp < 6000:
        xp_log = "Prata"
    elif exp >= 6001 and exp < 7000:
        xp_log = "Ouro"        
    elif exp >= 7001 and exp < 8000:
        xp_log = "Platina"
    elif exp >= 8001 and exp < 9000:
        xp_log = "Ascendente"
    elif exp >= 9001 and exp < 10000:
        xp_log = "Imortal"
    elif exp >= 10001:
        xp_log = "Radiante"
    
    Final()
def Final():
    print(f'O Herói {nome} está no nivel {xp_log} com {exp} pontos de experiência.')
    Jogo()
Jogo()
# Out:
# O herói  tem 0 pontos de experiência.
# Vamos treinar esse heroi?
# 1 - Vamos comer Salada - Acrescentar 1.000 pontos de experiência
# 2 - Levantar barras de FERRO acrescenta 5.000 pontos de experiência
# 3 - Comer um quadrado de Chocolate acrescenta 10.000 pontos de experiência
# 4 - Comer uma barra de Chocolate - 'Se uma quadrado dá isso de pontos...'
# 5 - Cansei da brincadeira
# Escolha uma opção válida,
# Você escolheu Raphael, atribuindo 0 pontos ao .
# O Herói  está no nivel FRANGO com 0 pontos de experiência.
# Vamos treinar esse heroi?
# 1 - Vamos comer Salada - Acrescentar 1.000 pontos de experiência
# 2 - Levantar barras de FERRO acrescenta 5.000 pontos de experiência
# 3 - Comer um quadrado de Chocolate acrescenta 10.000 pontos de experiência
# 4 - Comer uma barra de Chocolate - 'Se uma quadrado dá isso de pontos...'
# 5 - Cansei da brincadeira
# Escolha saudável
# Você escolheu 1, atribuindo 1000 pontos ao .
# ...
